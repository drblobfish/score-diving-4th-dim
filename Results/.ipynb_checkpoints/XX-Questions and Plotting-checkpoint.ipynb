# %% [markdown]
# # controling how people improve during the 4 experiments
#
# ### comparing the scores with respect to experiment order
# ### comparing the VR vs VR (1st vs 2nd) and same for Comp
# ### compare 1st and 2nd dataset on each platform for X Y and Z score
# ### compare pause time in VR and comp

# %% [markdown]
# # How does global shape comprehension compare on computer and in VR ?

# %% [markdown]
# ### Is there a significant difference in truth proportion between Comp and VR experiments ? We will compare experiment of the same experiment order between each other
# Box or Violin plot Truth % on Comp and VR depending on the software order (four categories)

# %% [markdown]
# ### Control : are the truth scores similar to those with random draw ?

# %% [markdown]
# # Does seeing the sequence in VR increases memory of it?

# %% [markdown]
# ### On average, is longest order streak longer in VR than that of Comp ? Same question with the Levenshtein distance ?
# --> t.test

# %% [markdown]
# ### Again, what part of these results are due to randomness

# %% [markdown]
# ### Capacity to deduce a sequence from the shapes --> are the streaks due to deduction or good memory ?
# Compare Longest streaks true and false

# %% [markdown]
# # Metadata

# %% [markdown]
# ### Does previous experience with VR and/or Computer have an impact the results (positive correlation ?)

# %% [markdown]
# ### How does evolve both type of score depending on the time paused ?
# --> Scatterplot ?

# %% [markdown]
# ### Overall, which factor has the most weight in scoring ? What is that of the hardware used ?
# --> Factor plot
